# %%
# personal and contact information
intro='This CV was created in Python programming language. Visit my Github page for details.'
name='Giorgi Beridze'
dob='DOB : Jan 12, 1997'
about_me="""
Hi, My name is Giorgi. I always liked mathematics and working with numbers.\n\
For the last two-three years, I've been passionately learning SQL and Python.\n\
Except for the working experience with automating reports using SQL and Python,\n\
I have also created a lot of Exploratory Data Analysis (EDA), Data Visaulization,\n\
Machine Learning, Web Scraping and other personal projects on Github and Kaggle.
"""
contact_information='Full Name : Giorgi Beridze \n\n\
Address : Tbilsi, Didi-Dighomi, \nMirian Mepe st. \n\n\
Tel : 595-88-78-92 \n\n\
Email : beridzeg45@gmail.com'

# websites
github='Github : https://github.com/beridzeg45'
kaggle='Kaggle : https://www.kaggle.com/beridzeg45/datasets'
linkedin='Linkedin : https://ge.linkedin.com/in/giorgi-beridze-0684b9167'

#languages and skills
languages='Georgian, English'
skills='-Python\n\
-Data Analysis\n\
-pandas\n\
-numpy\n\
-Data Visualization\n\
-matplotlib\n\
-seaborn\n\
-plotly\n\
-Machine LEarning\n\
-scikit-learn\n\
-Web Scraping\n\
-BeautifulSoup\n\
-selenium\n\
-SQL Server (MS SQL)\n\
-MySQL\n\
-Excel\n\
-Power BI'

#experience
work_header = 'EXPERIENCE'
work_one_title = 'Elit Electronics / Sales Consultant'
work_one_time = 'Jun 2019 - Sep 2019'
work_two_title = 'Madart / Jurnior Accountant And Reporting'
work_two_time = 'Oct 2021 - Apr 2021'
work_three_title = 'Zooplus / External Support Agent (Quality And Assurance)'
work_three_time = 'Apr 2021 - Present'

#education
edu_header = 'EDUCATION'
edu_one_title = '42nd Physics- Mathematical Public School Named After \nAcademician Ilia Vekua'
edu_one_time = '2009-2015'
edu_two_title = 'Agricultural University Of Georgia / Bachelor of Business Administration'
edu_two_time = '2015-2021'
edu_three_title = 'International Black Sea University (IBSU) / Masters Of Finance'
edu_three_time= '2022 - Present'



# setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline
# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'
fig, ax = plt.subplots(figsize=(8.5, 15))
# decorative lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='red', alpha=0.5, linewidth=300)
plt.axhline(y=.82, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=.70, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=.45, xmin=0, xmax=1, color='#ffffff', linewidth=3)
plt.axhline(y=.38, xmin=0, xmax=1, color='#ffffff', linewidth=3)


# set background color
ax.set_facecolor('white')
# remove axes
plt.axis('off')

# add personal information
plt.annotate(intro, (0.02,1), weight='regular', fontsize=8)
plt.annotate(name, (0.02,0.96), weight='bold', fontsize=20)
plt.annotate(dob, (0.02,0.94), weight='bold', fontsize=9)
plt.annotate(about_me, (0.02,0.83), weight='regular', fontsize=9)


#add contact information
plt.annotate('Contact Information : ',(0.7,.98),weight='bold',fontsize=10,color='#ffffff',textcoords='offset points',xytext=(0,0))
plt.annotate(contact_information, (0.7,.87), weight='regular', fontsize=9, color='#ffffff', textcoords='offset points',xytext=(0,0))

# add links
plt.annotate('Links : ',(0.7,.80),weight='bold',fontsize=10,color='#ffffff',textcoords='offset points',xytext=(0,0))
plt.annotate(github, (0.7,.77), weight='regular', fontsize=9, color='#ffffff', textcoords='offset points',xytext=(0,0))
plt.annotate(kaggle, (0.7,.75), weight='regular', fontsize=9, color='#ffffff', textcoords='offset points',xytext=(0,0))
plt.annotate(linkedin, (0.7,.73), weight='regular', fontsize=9, color='#ffffff', textcoords='offset points',xytext=(0,0))

# add skills and languages
plt.annotate('Skills :', (0.7,.68), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(skills, (0.7,.47), weight='regular', fontsize=9, color='#ffffff')
plt.annotate('Languages :', (0.7,.43), weight='bold', fontsize=9, color='#ffffff')
plt.annotate(languages, (0.7,.41), weight='regular', fontsize=9, color='#ffffff')

# add education
plt.annotate(edu_header, (.02,.79), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(edu_one_title, (.02,.75), weight='bold', fontsize=9)
plt.annotate(edu_one_time, (.02,.73), weight='regular', fontsize=9, alpha=.6)
plt.annotate(edu_two_title, (.02,.70), weight='bold', fontsize=9)
plt.annotate(edu_two_time, (.02,.68), weight='regular', fontsize=9, alpha=.6)
plt.annotate(edu_three_title, (.02,.65), weight='bold', fontsize=9)
plt.annotate(edu_three_time, (.02,.63), weight='regular', fontsize=9, alpha=.6)

# add experience
plt.annotate(work_header, (.02,.58), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(work_one_title, (.02,.54), weight='bold', fontsize=10)
plt.annotate(work_one_time, (.02,.52), weight='regular', fontsize=9, alpha=.6)
plt.annotate(work_two_title, (.02,.49), weight='bold', fontsize=10)
plt.annotate(work_two_time, (.02,.47), weight='regular', fontsize=9, alpha=.6)
plt.annotate(work_three_title, (.02,.44), weight='bold', fontsize=10)
plt.annotate(work_three_time, (.02,.42), weight='regular', fontsize=9, alpha=.6)

plt.savefig('Giorgi Beridze CV (Eng).pdf', dpi=300, bbox_inches='tight')
